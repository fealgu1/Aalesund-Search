# %%
import requests
import requests
from urllib.parse import urlencode
import pandas as pd
import numpy as np
# Out:
# C:\Users\fealg\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
api_key= "xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx"

# %% [markdown]
# ### Google Cloud Platform Tutorial

# %%
def extract_lat_lng(address_or_postalcode, data_type = 'json'):
    endpoint = f"https://maps.googleapis.com/maps/api/geocode/{data_type}"
    params = {"address": address_or_postalcode, "key": api_key}
    url_params = urlencode(params)
    url = f"{endpoint}?{url_params}"
    r = requests.get(url)
    if r.status_code not in range(200, 299): 
        return {}
    latlng = {}
    try:
        latlng = r.json()['results'][0]['geometry']['location']
    except:
        pass
    return latlng.get("lat"), latlng.get("lng")

# %% [markdown]
# #### Testing code

# %%
extract_lat_lng("1600 Amphitheatre Parkway, Mountain View, CA")
# Out:
# (37.4223878, -122.0841877)

# %%
from urllib.parse import urlparse, parse_qsl
to_parse = sample = "https://maps.googleapis.com/maps/api/geocode/json?place_id=ChIJeRpOeF67j4AR9ydy_PIzPuM&key=api_key"

# %%
urlparse(to_parse)
# Out:
# ParseResult(scheme='https', netloc='maps.googleapis.com', path='/maps/api/geocode/json', params='', query='place_id=ChIJeRpOeF67j4AR9ydy_PIzPuM&key=api_key', fragment='')

# %%
parsed_url = urlparse(to_parse)
query_string = parsed_url.query
query_string
# Out:
# 'place_id=ChIJeRpOeF67j4AR9ydy_PIzPuM&key=api_key'

# %%
query_tuple = parse_qsl(query_string)
print(query_tuple)
# Out:
# [('place_id', 'ChIJeRpOeF67j4AR9ydy_PIzPuM'), ('key', 'api_key')]

# %%
query_dict = dict(query_tuple)
query_dict
# Out:
# {'place_id': 'ChIJeRpOeF67j4AR9ydy_PIzPuM', 'key': 'api_key'}

# %% [markdown]
# ## Extract Restaurant Information
#
# * The Google API searches for restaurant using a circular area of 5000 meters.

# %%
lat, lng = 62.473060, 6.155634 # Aalesund
base_endpoint_places = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json"
params = {
    "key": api_key,
    "input": "Restaurant",
    "inputtype": "textquery",
    "fields": "place_id,formatted_address,name,geometry,permanently_closed"
}
locationbias = f"point:{lat},{lng}"
use_cirular = True
if use_cirular:
    radius = 5000
    locationbias = f"circle:{radius}@{lat},{lng}"

params['locationbias'] = locationbias

params_encoded = urlencode(params)
places_endpoint = f"{base_endpoint_places}?{params_encoded}"
print(places_endpoint)
# Out:
# https://maps.googleapis.com/maps/api/place/findplacefromtext/json?key=AIzaSyAA4sQINXPpT8tWTeRYvD8RduaorS351uQ&input=Restaurant&inputtype=textquery&fields=place_id%2Cformatted_address%2Cname%2Cgeometry%2Cpermanently_closed&locationbias=circle%3A5000%4062.47306%2C6.155634

# %%
r = requests.get(places_endpoint)
print(r.status_code)
# Out:
# 200

# %% [markdown]
# ## Code for Aalesund.

# %%
places_endpoint_2 = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params_2 = {
    "key": api_key,
    "location": f"{lat},{lng}",
    "radius": 5000,
    "keyword": "burger"
}
params_2_encoded = urlencode(params_2)
places_url = f"{places_endpoint_2}?{params_2_encoded}"

r2 = requests.get(places_url)
jsrults = r2.json()['results']

# %%
df = pd.json_normalize(jsrults)
df
# Out:
#    business_status                                               icon
# 0      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...  \
# 1      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 5      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 6      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 7      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 8      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 9      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 10     OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11     OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# ...

# %%
df.columns
# Out:
# Index(['business_status', 'icon', 'icon_background_color',
#        'icon_mask_base_uri', 'name', 'photos', 'place_id', 'rating',
#        'reference', 'scope', 'types', 'user_ratings_total', 'vicinity',
#        'geometry.location.lat', 'geometry.location.lng',
#        'geometry.viewport.northeast.lat', 'geometry.viewport.northeast.lng',
#        'geometry.viewport.southwest.lat', 'geometry.viewport.southwest.lng',
#        'opening_hours.open_now', 'plus_code.compound_code',
#        'plus_code.global_code', 'price_level'],
#       dtype='object')

# %%
Pizza = df[['business_status','name','rating','user_ratings_total','price_level','plus_code.compound_code']]
Pizza
# Out:
#   business_status                                 name  rating
# 0     OPERATIONAL  Nonna Lina ristorante pizzeria café     4.5  \
# 1     OPERATIONAL  Emil's Burger & Kebab House Ålesund     4.1
# 2     OPERATIONAL            Steinovnen Bar & Pizzeria     4.2
# 3     OPERATIONAL                        Cinque minuti     4.6
# 4     OPERATIONAL              Pizzabakeren Øysenteret     4.2
#
#    user_ratings_total  price_level            plus_code.compound_code
# 0                 740          2.0            F5C4+GF Ålesund, Norway
# 1                 107          NaN            F5C2+J7 Ålesund, Norway
# 2                 358          2.0            F5C8+Q8 Ålesund, Norway
# 3                 476          2.0            F5F4+GR Ålesund, Norway
# 4                  92          2.0  F4XJ+Q9 Valderhaugstranda, Norway

# %%
Bakeri = df[['business_status','name','rating','user_ratings_total','price_level','plus_code.compound_code']]
Bakeri
# Out:
#   business_status                                   name  rating
# 0     OPERATIONAL                         Valaker bakeri     3.9  \
# 1     OPERATIONAL                                Valaker     3.9
# 2     OPERATIONAL    Walderhaug Bakery and Confectionery     4.4
# 3     OPERATIONAL                              Bakerinnå     5.0
# 4     OPERATIONAL  Flobeu | Bakeri - Konditori | Ålesund     5.0
# 5     OPERATIONAL               Deig-lig Homemade sweets     5.0
# 6     OPERATIONAL                            N.A Dessert     5.0
# 7     OPERATIONAL                         Devie's Donuts     5.0
#
#    user_ratings_total  price_level  plus_code.compound_code
# 0                  48          NaN  F5C3+FF Ålesund, Norway
# 1                  56          NaN  F5F5+3G Ålesund, Norway
# 2                 385          2.0  F5G4+22 Ålesund, Norway
# 3                   8          NaN  F5C3+MW Ålesund, Norway
# 4                   6          NaN  F5C5+H2 Ålesund, Norway
# ...

# %%
Sushi = df[['business_status','name','rating','user_ratings_total','price_level','plus_code.compound_code']]
Sushi
# Out:
#        business_status                        name  rating
# 0          OPERATIONAL               Ålesund sushi     4.1  \
# 1          OPERATIONAL                   T&T Sushi     3.6
# 2          OPERATIONAL                       Zuuma     4.4
# 3          OPERATIONAL  Fisketorget Delikatesse AS     4.6
# 4          OPERATIONAL                  Thong Thai     4.7
# 5   CLOSED_TEMPORARILY    Orient Restaurant og Bar     4.3
# 6          OPERATIONAL       Long Cheng Restaurant     3.9
# 7          OPERATIONAL                      Sjøbua     4.4
# 8          OPERATIONAL                   Krua Thai     4.3
# 9          OPERATIONAL                   Wok&Grill     4.5
# 10         OPERATIONAL               Express Pizza     4.2
# 11         OPERATIONAL           Sāma Golden Kebab     4.2
# 12         OPERATIONAL       Krua Thai Takeaway AS     0.0
#
#     user_ratings_total  price_level            plus_code.compound_code
# ...

# %%
Burger = df[['business_status','name','rating','user_ratings_total','price_level','plus_code.compound_code']]
Burger
# Out:
#    business_status                                 name  rating
# 0      OPERATIONAL       Burger King Ålesund Storsenter     3.6  \
# 1      OPERATIONAL  Emil's Burger & Kebab House Ålesund     4.1
# 2      OPERATIONAL                       The Greedy Box     4.8
# 3      OPERATIONAL         The Real American Steakhouse     3.8
# 4      OPERATIONAL  Happy Elefante - Bar, Grill & Music     4.2
# 5      OPERATIONAL                            Molo Brew     4.4
# 6      OPERATIONAL                                 Jafs     4.2
# 7      OPERATIONAL          Emil's Burger & Kebab House     4.0
# 8      OPERATIONAL                           Kebab King     4.2
# 9      OPERATIONAL                             Stuen AS     4.5
# 10     OPERATIONAL                                 Egon     3.9
# 11     OPERATIONAL         Anno Restaurant & Lounge Bar     4.3
# 12     OPERATIONAL              Bulls Brygge Restaurant     2.7
# 13     OPERATIONAL           Pluto Kiosk og Gatekjøkken     4.2
# ...

# %%
Asian = df[['business_status','name','rating','user_ratings_total','price_level','plus_code.compound_code']]
Asian
# Out:
#        business_status                          name  rating
# 0          OPERATIONAL             Unchoo Asian Food     5.0  \
# 1          OPERATIONAL                 Restaurant HK     4.4
# 2          OPERATIONAL         Long Cheng Restaurant     3.9
# 3          OPERATIONAL         Torghallen Dagligvare     4.1
# 4          OPERATIONAL    SOI ONE - Thai Street Food     4.5
# 5          OPERATIONAL                     Padmax AS     4.4
# 6          OPERATIONAL                     Wok&Grill     4.5
# 7          OPERATIONAL             Ålesund Asia Shop     4.5
# 8          OPERATIONAL                 Rotsabieng AS     4.8
# 9   CLOSED_TEMPORARILY      Orient Restaurant og Bar     4.3
# 10         OPERATIONAL               Fumo Cafe & Bar     4.8
# 11         OPERATIONAL                     Krua Thai     4.3
# 12         OPERATIONAL  Tajmahal Tandoori Restaurant     4.0
# 13         OPERATIONAL                         Zuuma     4.4
# ...

# %%
Grill = df[['business_status','name','rating','user_ratings_total','price_level','plus_code.compound_code']]
Grill
# Out:
#        business_status                                    name  rating
# 0          OPERATIONAL                               Wok&Grill     4.5  \
# 1          OPERATIONAL     Happy Elefante - Bar, Grill & Music     4.2
# 2          OPERATIONAL            The Real American Steakhouse     3.8
# 3          OPERATIONAL                           Express Pizza     4.2
# 4          OPERATIONAL                                   Zuuma     4.4
# 5          OPERATIONAL                       Yamma Pizza Kebab     0.0
# 6          OPERATIONAL                              Master Mat     4.0
# 7          OPERATIONAL              Pluto Kiosk og Gatekjøkken     4.2
# 8          OPERATIONAL                          The Greedy Box     4.8
# 9          OPERATIONAL  Ålesund Kebab Shawerma & Pizza (Halal)     4.1
# 10         OPERATIONAL            Tajmahal Tandoori Restaurant     4.0
# 11         OPERATIONAL                           Dampsentralen     4.2
# ...

# %%
bowl = df[['business_status','name','rating','user_ratings_total','price_level','plus_code.compound_code']]
bowl
# Out:
#    business_status                                name  rating
# 0      OPERATIONAL                                Egon     3.9  \
# 1      OPERATIONAL  Tante Bruun interior and design AS     4.2
# 2      OPERATIONAL                       Ålesund sushi     4.1
# 3      OPERATIONAL                   EVERGREENS BISTRO     4.6
# 4      OPERATIONAL                               Zuuma     4.4
# 5      OPERATIONAL          Fisketorget Delikatesse AS     4.6
# 6      OPERATIONAL        Tajmahal Tandoori Restaurant     4.0
# 7      OPERATIONAL                 Gyros House Ålesund     4.4
# 8      OPERATIONAL                REMA 1000 STRANDGATA     4.3
# 9      OPERATIONAL                  REMA 1000 LANGEVÅG     4.2
# 10     OPERATIONAL                            XL Diner     4.5
# 11     OPERATIONAL                   Europris Langevåg     4.3
# 12     OPERATIONAL          Kitch'n Ålesund Storsenter     4.4
# 13     OPERATIONAL                    KIWI Klokkersund     4.2
# ...

# %%
Indian= df[['business_status','name','rating','user_ratings_total','price_level','plus_code.compound_code']]
Indian
# Out:
#   business_status                          name  rating  user_ratings_total
# 0     OPERATIONAL  Tajmahal Tandoori Restaurant       4                 509  \
#
#    price_level  plus_code.compound_code
# 0            2  F5G4+4J Ålesund, Norway

# %%
Kebab = df[['business_status','name','rating','user_ratings_total','price_level','plus_code.compound_code']]
Kebab
# Out:
#    business_status                                    name  rating
# 0      OPERATIONAL                       Sāma Golden Kebab     4.2  \
# 1      OPERATIONAL             Emil's Burger & Kebab House     4.0
# 2      OPERATIONAL                              Kebab King     4.2
# 3      OPERATIONAL                       Yamma Pizza Kebab     0.0
# 4      OPERATIONAL                              Master Mat     4.0
# 5      OPERATIONAL  Ålesund Kebab Shawerma & Pizza (Halal)     4.1
# 6      OPERATIONAL                           Express Pizza     4.2
# 7      OPERATIONAL                                    Jafs     4.2
# 8      OPERATIONAL                              Lamella As     0.0
# 9      OPERATIONAL                          Lille Aalesund     4.0
# 10     OPERATIONAL              Pluto Kiosk og Gatekjøkken     4.2
# 11     OPERATIONAL            Tajmahal Tandoori Restaurant     4.0
# 12     OPERATIONAL                       Smultringhuset AS     4.0
# ...

# %%
Italian= df[['business_status','name','rating','user_ratings_total','price_level','plus_code.compound_code']]
Italian
# Out:
#    business_status                                    name  rating
# 0      OPERATIONAL     Nonna Lina ristorante pizzeria café     4.5  \
# 1      OPERATIONAL                           Cinque minuti     4.6
# 2      OPERATIONAL               Steinovnen Bar & Pizzeria     4.2
# 3      OPERATIONAL                         Italian Home AS     0.0
# 4      OPERATIONAL            Anno Restaurant & Lounge Bar     4.3
# 5      OPERATIONAL                                XL Diner     4.5
# 6      OPERATIONAL  Ålesund Kebab Shawerma & Pizza (Halal)     4.1
# 7      OPERATIONAL                  Let’s Eat Deli Ålesund     4.5
# 8      OPERATIONAL                                Vino Bar     4.8
# 9      OPERATIONAL                                    Egon     3.9
# 10     OPERATIONAL                           Dampsentralen     4.2
# 11     OPERATIONAL                           Rotsabieng AS     4.8
# 12     OPERATIONAL                               Krua Thai     4.3
# ...

# %%
Cafe = df[['business_status','name','rating','user_ratings_total','price_level','plus_code.compound_code']]
Cafe
# Out:
#        business_status                                 name  rating
# 0          OPERATIONAL               Dråpe Ålesund Kaffehus     4.5  \
# 1          OPERATIONAL                        Racoon Coffee     4.5
# 2          OPERATIONAL                      Apoteker'n Café     4.2
# 3          OPERATIONAL                  Kafé Kremmergaarden     4.2
# 4          OPERATIONAL                        Café Mio, Mio     0.0
# 5          OPERATIONAL                         Kantina kafé     4.3
# 6          OPERATIONAL   Tante Bruun interior and design AS     4.2
# 7          OPERATIONAL                             Maru Cha     4.5
# 8          OPERATIONAL                    Bymisjonssenteret     4.5
# 9          OPERATIONAL                      Fumo Cafe & Bar     4.8
# 10         OPERATIONAL                               Kølbua     4.8
# 11         OPERATIONAL                       Valaker bakeri     3.9
# 12         OPERATIONAL               Let’s Eat Deli Ålesund     4.5
# ...

# %%
Indian["Type"] = "Indian"
Indian
# Out:
# <ipython-input-157-c7e81b01a435>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Indian["Type"] = "Indian"
#   business_status                          name  rating  user_ratings_total
# 0     OPERATIONAL  Tajmahal Tandoori Restaurant       4                 509  \
#
#    price_level  plus_code.compound_code    Type
# 0            2  F5G4+4J Ålesund, Norway  Indian

# %%
Indian = Indian.drop('col3', axis =1)
Indian
# Out:
#   business_status                          name  rating  user_ratings_total
# 0     OPERATIONAL  Tajmahal Tandoori Restaurant       4                 509  \
#
#    price_level  plus_code.compound_code    Type
# 0            2  F5G4+4J Ålesund, Norway  Indian

# %%
Bakeri.insert(6, 'Type', 'Bakeri')
Bakeri.iloc[:, [6]]

Burger.insert(6, 'Type', 'Burger')
Burger.iloc[:, [6]]

bowl.insert(6, 'Type', 'Bowl')
bowl.iloc[:, [6]]

Cafe.insert(6, 'Type', 'Cafe')
Cafe.iloc[:, [6]]

Asian.insert(6, 'Type', 'Asian')
Asian.iloc[:, [6]]

Pizza.insert(6, 'Type', 'Pizza')
Pizza.iloc[:, [6]]

Italian.insert(6, 'Type', 'Italian')
Italian.iloc[:, [6]]

Kebab.insert(6, 'Type', 'Kebab')
Italian.iloc[:, [6]]

Grill.insert(6, 'Type', 'Grill')
Grill.iloc[:, [6]]

Sushi.insert(6, 'Type', 'Sushi')
Sushi.iloc[:, [6]]

# %%
Alesun = pd.concat([Bakeri,Burger,bowl,Cafe,Asian,Pizza,Italian,Kebab,Grill,Sushi], axis=0)
Alesun
# Out:
#    business_status                                   name  rating
# 0      OPERATIONAL                         Valaker bakeri     3.9  \
# 1      OPERATIONAL                                Valaker     3.9
# 2      OPERATIONAL    Walderhaug Bakery and Confectionery     4.4
# 3      OPERATIONAL                              Bakerinnå     5.0
# 4      OPERATIONAL  Flobeu | Bakeri - Konditori | Ålesund     5.0
# ..             ...                                    ...     ...
# 8      OPERATIONAL                              Krua Thai     4.3
# 9      OPERATIONAL                              Wok&Grill     4.5
# 10     OPERATIONAL                          Express Pizza     4.2
# 11     OPERATIONAL                      Sāma Golden Kebab     4.2
# 12     OPERATIONAL                  Krua Thai Takeaway AS     0.0
#
#     user_ratings_total  price_level  plus_code.compound_code    Type
# 0                   48          NaN  F5C3+FF Ålesund, Norway  Bakeri
# ...

# %%
Alesun.to_csv("An.csv", encoding='utf-16', sep = ',')

# %%
NoVenues = pd.read_clipboard()

# %%
NoVenues.name.value_counts(normalize = True)*100
# Out:
# name
# 6.0    38.299419
# 7.0    15.988372
# 9.0     9.338663
# 2.0     9.229651
# 3.0     7.594477
# 5.0     7.231105
# 4.0     5.777616
# 1.0     4.614826
# 8.0     1.925872
# Name: proportion, dtype: float64
